# %%
#------------ USANDO CNN to classify CIFAR images. -----------------
from __future__ import absolute_import, division, print_function, unicode_literals
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt

'''
The CIFAR10 dataset contains 60,000 color images in 10 classes, 
with 6,000 images in each class. The dataset is divided into 
50,000 training images and 10,000 testing images. 
The classes are mutually exclusive and there is no overlap
between them.
'''
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()
#Normalize pixel values to be between 0 and 1
train_images, test_images = train_images / 255.0, test_images / 255.0

#Verify the dataset images. Plottingg 25 images
class_names = ['airplane', 'automobile' , 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'shihp', 'truck']


plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i][0]])
plt.show()

#CRIANDO A BASE CONVULACIONAL
#A entrada da CNN serah 32 x 32 x 3, onde img_height x img_width x color_channels
#Layers Convolutional and Pooling
model = models.Sequential()
model.add(layers.Conv2D(32, (3,3), activation='relu', input_shape=(32,32,3)))
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Conv2D(64, (3,3), activation='relu'))
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Conv2D(64,(3,3), activation='relu'))

#Layer Fully complete
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))

#Compilando e treinando o modelo
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(train_images, train_labels, epochs=10,
                   validation_data=(test_images, test_labels))

model.summary()

#Plotting of evaluation
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')
test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 79s 2ms/sample - loss: 1.5235 - acc: 0.4436 - val_loss: 1.2614 - val_acc: 0.5399
# Epoch 2/10
# 50000/50000 [==============================] - 79s 2ms/sample - loss: 1.1647 - acc: 0.5875 - val_loss: 1.1178 - val_acc: 0.6025
# Epoch 3/10
# 50000/50000 [==============================] - 78s 2ms/sample - loss: 1.0126 - acc: 0.6449 - val_loss: 0.9858 - val_acc: 0.6513
# Epoch 4/10
# 50000/50000 [==============================] - 79s 2ms/sample - loss: 0.9128 - acc: 0.6804 - val_loss: 1.0049 - val_acc: 0.6510
# Epoch 5/10
# 50000/50000 [==============================] - 79s 2ms/sample - loss: 0.8407 - acc: 0.7054 - val_loss: 0.9458 - val_acc: 0.6722
# Epoch 6/10
# 50000/50000 [==============================] - 78s 2ms/sample - loss: 0.7783 - acc: 0.7281 - val_loss: 0.9294 - val_acc: 0.6809
# Epoch 7/10
# 50000/50000 [==============================] - 78s 2ms/sample - loss: 0.7295 - acc: 0.7451 - val_loss: 0.8712 - val_acc: 0.7035
# Epoch 8/10
# 50000/50000 [==============================] - 78s 2ms/sample - loss: 0.6797 - acc: 0.7622 - val_loss: 0.8675 - val_acc: 0.7032
# Epoch 9/10
# 50000/50000 [==============================] - 78s 2ms/sample - loss: 0.6395 - acc: 0.7762 - val_loss: 0.8748 - val_acc: 0.7017
# Epoch 10/10
# 50000/50000 [==============================] - 79s 2ms/sample - loss: 0.5995 - acc: 0.7877 - val_loss: 0.9046 - val_acc: 0.7021
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_9 (Conv2D)            (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 13, 13, 64)        18496
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 4, 4, 64)          36928
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_14 (Dense)             (None, 64)                65600
# _________________________________________________________________
# dense_15 (Dense)             (None, 10)                650
# =================================================================
# Total params: 122,570
# Trainable params: 122,570
# Non-trainable params: 0
# _________________________________________________________________
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-950637b31b7d> in <module>
#      57
#      58 #Plotting of evaluation
# ---> 59 plt.plot(history.history['accuracy'], label='accuracy')
#      60 plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
#      61 plt.xlabel('Epoch')
#
# KeyError: 'accuracy'

# %%
#USANDO UMA REDE PARA CLASSICATION

from __future__ import absolute_import, division, print_function, unicode_literals

#TensorFlow e tf.keras
import tensorflow as tf
from tensorflow import keras

#Libraries Auxiliares
import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)

#Importando Fashion MNIST diretamente do Tensorflow
fashion_mnist = keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

class_names = ['T-Shirt/Top', 'Trouser', 'Pullover', 'Dress', 'Coat',
                'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

#Mostrando qtd de imagens e seu tamanho no treinamento
train_images.shape

#Mosrando labels no conjunto de trainamento
len(train_labels)

train_labels

#Mostrando qtd de imagens do Test
test_images.shape

#Mosrando labels no conjunto de Teste
len(test_labels)

test_labels

#Plotando imagem antes de pré-processados. Note que esta de 0 a 255
plt.figure()
plt.imshow(train_images[0])
plt.colorbar()
plt.grid(False)
plt.show()

#Escalaremos esses valores entre 0 e 1
train_images = train_images / 255.0
test_images = test_images / 255.0

#Antes de construir a rede, vejamos as imagens
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])
plt.show()

#Construindo o modelo
#Montando as camadas
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)), #1º camada da rede, transforma array de 2D para 1D=784pixels
    keras.layers.Dense(128, activation='relu'), #2º camada com 128 nós
    keras.layers.Dense(10, activation='softmax') #3º camda com 10 nós
])

#Compilando o modelo
model.compile(optimizer='adam', #como o modelo se atualiza com base no dado que ele ve e sua funcao loss
              loss='sparse_categorical_crossentropy', #Esse mede quão precisa o modelo é durante o treinamento.
              metrics=['accuracy']) #para monitorar os passos de treinamento e teste

#Treinando o modelo
#Para começar a treinar use o método "model.fit". Este vai encaixar o modelo no conjunto de treinamento
model.fit(train_images, train_labels, epochs=10)

#Avaliando acurácia
test_loss, test_acc = model.evaluate(test_images, test_labels, verbose=2)
print('\nTest Accuracy:', test_acc)

#Fazendo predições
predictions = model.predict(test_images)

#A predição eh um array de 10 numeros, que representa a confiança
#do modelo que a imagem corresponde a cada um dos artigos de roupa
predictions[0] #verifiacando o item 0

np.argmax(predictions[0]) #mostrando o maior indicie de confianca
test_labels[0] #O numero de predicao eh igual ao label
# Out:
# 1.13.2
# Epoch 1/10
# 60000/60000 [==============================] - 8s 128us/sample - loss: 0.5031 - acc: 0.8240
# Epoch 2/10
# 60000/60000 [==============================] - 7s 123us/sample - loss: 0.3813 - acc: 0.8625
# Epoch 3/10
# 60000/60000 [==============================] - 7s 119us/sample - loss: 0.3427 - acc: 0.8760
# Epoch 4/10
# 60000/60000 [==============================] - 7s 123us/sample - loss: 0.3175 - acc: 0.8840
# Epoch 5/10
# 60000/60000 [==============================] - 8s 132us/sample - loss: 0.2983 - acc: 0.8895
# Epoch 6/10
# 60000/60000 [==============================] - 8s 136us/sample - loss: 0.2816 - acc: 0.8951
# Epoch 7/10
# 60000/60000 [==============================] - 7s 114us/sample - loss: 0.2708 - acc: 0.8994
# Epoch 8/10
# 60000/60000 [==============================] - 7s 118us/sample - loss: 0.2593 - acc: 0.9038
# Epoch 9/10
# 60000/60000 [==============================] - 7s 122us/sample - loss: 0.2505 - acc: 0.9055
# Epoch 10/10
# 60000/60000 [==============================] - 8s 125us/sample - loss: 0.2400 - acc: 0.9091
#  - 1s - loss: 0.3355 - acc: 0.8824
#
# Test Accuracy: 0.8824
# 9
